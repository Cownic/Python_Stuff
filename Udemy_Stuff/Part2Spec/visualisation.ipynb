# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('resulting_data.csv')
df = pd.DataFrame(data)
print(df)
# Out:
#     Number of Retweets  Number of Replies  Positive Score  Negative Score  \
# 0                    3                  0               0               0
# 1                    1                  0               2               2
# 2                    1                  2               1               0
# 3                    3                  1               1               0
# 4                    6                  0               2               0
# 5                    9                  5               2               0
# 6                   19                  0               2               0
# 7                    0                  0               0               3
# 8                    0                  0               0               2
# 9                   82                  2               4               0
# 10                   0                  0               0               1
# 11                   0                  0               1               0
# ...

# %%
plt.scatter(df['Net Score'], df['Number of Retweets'])
plt.title('Sentiment Classifer Results')
plt.xlabel('Net Score')
plt.ylabel('Number of Retweet')
plt.show()
